# %% [markdown]
# <a href="https://colab.research.google.com/github/IA-Programming/Curso-Introductorio-Langchain/blob/main/conceptos/lab/l7-embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalando todas las librerías necesarias

# %%
# !pip install langchain openai langchain_openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.4/802.4 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.6/218.6 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
# ...

# %% [markdown]
# # Configurando el entorno de trabajo

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")
# Out:
# Enter your OpenAI API key: ··········

# %% [markdown]
# # Embeddings

# %%
import os
from langchain_openai import OpenAIEmbeddings

embeddings_model = OpenAIEmbeddings(api_key=os.getenv('OPENAI_API_KEY'))

# %%
text = "This is a test document."

# %%
texts = ["This is a test", "This is another test"]

# %%
query_result = embeddings_model.embed_query(text)

# %%
doc_result = embeddings_model.embed_documents(texts)

# %%
print(query_result)
# Out:
# [-0.003105442842703499, 0.011136301333111021, -0.004029582553785511, -0.01174906406444312, -0.0010406979861090607, 0.010789957383080386, -0.010357026514219558, -0.005298401941526072, -0.009917435757902777, -0.026148994304343896, 0.020341067665939603, 0.0225923052037838, -0.007519667657512144, 0.01725060980284263, -0.006007741422872291, 0.019168825028213165, 0.02126021222859902, -0.015598814290096094, 0.007639555876267168, -0.018356247978074336, -0.0007051769934785912, -0.006414029947941705, -0.010969789245551656, 0.017969940978017847, -0.022126072103675603, -0.003042168323936743, 0.014373288827431899, -0.02997210311752799, 0.0184894569030638, -0.007939276888815999, 0.010050645614214777, -0.01942192310328019, -0.0036898989568720964, -0.024270742128999212, -0.005501546204060779, 0.003819777938133584, -0.005658067063452413, -0.029465906967393943, 0.018542741590646627, -0.01662452636527609, 0.0075063464856164365, 0.01246173442083985, -0.0009666003353191643, -0.01069671057679424, 0.010024
# ...

# %%
print(doc_result)
# Out:
# [[-0.008059182232837327, -0.003603511269854313, -0.0005280580972389248, -0.005753727650150176, -0.024468205955820443, 0.01613157620776492, -0.014929304883582843, -0.0046340297140322695, -0.0009636337670153324, -0.03445630532780456, 0.015920188334320642, 0.017267787890173084, -0.008997217783891478, 0.0022311383005987513, 0.008713165328950724, 1.3005340452421771e-05, 0.02448141769791071, 0.0005771893795524294, 0.008336629748055522, -0.00744483482865602, 0.0054465537152288785, 0.007563740507468428, -0.011547090526571154, 0.024838134734347934, -0.028352467443584876, -0.02319987498986445, 0.0035044229713466625, -0.03522259009433039, 0.019421307438822158, -0.009941860137313338, 0.021878697055547385, -0.017347060205359845, 0.001747257082389481, -0.036332380155203174, 0.0007807332467919024, -0.012676697269256762, -0.010609054975517005, -0.017294211374353618, 0.008019547006566524, -0.010886501559412622, 0.0091623654913424, 0.016686471238201314, 0.007147569700302423, -0.021337015629846415, -0.
# ...

# %%
print(len(query_result), len(doc_result), len(doc_result[0]))
# Out:
# 1536 2 1536

# %%
type(query_result)
# Out:
# list

# %% [markdown]
# # Testing

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def compute_cosine_similarity(u: np.ndarray, v: np.ndarray) -> float:
    """Compute the cosine similarity between two vectors"""

    return (u @ v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
dog_embedding = embeddings_model.embed_query("dog")
cat_embedding = embeddings_model.embed_query("cat")
apple_embedding = embeddings_model.embed_query("apple")
tasty_embedding = embeddings_model.embed_query("tasty")
delicious_embedding = embeddings_model.embed_query("delicious")
truck_embedding = embeddings_model.embed_query("truck")

# %%
type(np.array(query_result))
# Out:
# numpy.ndarray

# %%
print ("----- SIMILARITIES -----")
print("cosine_similarity(dog, cat)")
print(cosine_similarity([dog_embedding], [cat_embedding])[0][0],"\n")

print("cosine_similarity(delicious, tasty)")
print(cosine_similarity([delicious_embedding], [tasty_embedding])[0][0],"\n")

print("cosine_similarity(apple, delicious)")
print(cosine_similarity([apple_embedding], [delicious_embedding])[0][0],"\n")

print("cosine_similarity(dog, apple)")
print(cosine_similarity([dog_embedding], [apple_embedding])[0][0],"\n")

print("cosine_similarity(truck, delicious)")
print(cosine_similarity([truck_embedding], [delicious_embedding])[0][0],"\n")
# Out:
# ----- SIMILARITIES -----
# cosine_similarity(dog, cat)
# 0.863684539093805
#
# cosine_similarity(delicious, tasty)
# 0.9337212467943936
#
# cosine_similarity(apple, delicious)
# 0.8090793457444218
#
# cosine_similarity(dog, apple)
# 0.8302912200652401
#
# cosine_similarity(truck, delicious)
# 0.779560860926224

# %%
print ("----- SIMILARITIES -----")
print("cosine_similarity(dog, cat)")
print(compute_cosine_similarity(np.array(dog_embedding), np.array(cat_embedding)),"\n")

print("cosine_similarity(delicious, tasty)")
print(compute_cosine_similarity(np.array(delicious_embedding), np.array(tasty_embedding)),"\n")

print("cosine_similarity(apple, delicious)")
print(compute_cosine_similarity(np.array(apple_embedding), np.array(delicious_embedding)),"\n")

print("cosine_similarity(dog, apple)")
print(compute_cosine_similarity(np.array(dog_embedding), np.array(apple_embedding)),"\n")

print("cosine_similarity(truck, delicious)")
print(compute_cosine_similarity(np.array(truck_embedding), np.array(delicious_embedding)),"\n")
# Out:
# ----- SIMILARITIES -----
# cosine_similarity(dog, cat)
# 0.8636845390938056
#
# cosine_similarity(delicious, tasty)
# 0.9337212467943936
#
# cosine_similarity(apple, delicious)
# 0.8090793457444223
#
# cosine_similarity(dog, apple)
# 0.8302912200652406
#
# cosine_similarity(truck, delicious)
# 0.7795608609262241
